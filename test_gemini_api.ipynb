# %% [markdown]
# ## Gemini API test
# 1, create an API key here, https://aistudio.google.com/api-keys
#
# 2, list available models
#
# 3, a sample prompt

# %%
from google import genai

client = genai.Client(api_key="AIzaSyCwubqpoBjLrsEy5f34Atdqc0sy96QtVXM")

# List available models and see which support generateContent
for m in client.models.list():
    # m.name often looks like "models/gemini-..." and includes supported methods/metadata
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# ...

# %%
response = client.models.generate_content(model='models/gemini-2.5-flash', contents='How does AI work?')
print(response.text)
# Out:
# AI, or Artificial Intelligence, works by enabling machines to simulate and perform tasks that typically require human intelligence. This involves a combination of data, algorithms, and computational power to recognize patterns, make decisions, solve problems, and even understand language or perceive the world.
#
# Let's break it down into its core components and processes:
#
# ## The Foundational Trio: Data, Algorithms, and Models
#
# 1.  **Data: The Fuel**
#     *   AI systems learn from data. Think of it as the raw material. The quality, quantity, and relevance of data are crucial.
#     *   **Examples:** Images, text, audio recordings, sensor readings, numerical tables, medical records.
#     *   **Purpose:**
#         *   **Training Data:** Used to teach the AI what to look for and how to react. For instance, to recognize cats, you feed it thousands of images labeled "cat" and "not cat."
# ...
